# %%
import poreflow as pf

# %%
filename = '/Users/iravaidya/Documents/Bachelors/BEP/raw_data/TUD257703_20250612_FBC75794_MN45752_sequencing_run_cDNA_Y_NoTranslation_column_pur_run1_20511.fast5'
f = pf.File(filename)

# %%
f.device
f.name
# Out:
# '/'

# %%
f.close()
