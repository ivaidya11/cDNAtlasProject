# %%
import sys, os
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..')))

from logic.cnn_logic import cnn_sweep
import numpy as np
import tensorflow as tf
from logic.database import AA_PROPERTIES
import pandas as pd
from logic.clustering_cnn import get_clusters

# %%
train_raw = pd.read_csv('../data/nanopore_feature_by_cluster.csv')
test_raw = pd.read_csv('../data/randomcontrol_feature_by_cluster.csv')

# %% [markdown]
# ### 4 Cluster CNN

# %%
model_4, history_4, X_test_4, y_test_4 = cnn_sweep(
    n_clusters=4, train=train_raw, test=test_raw
    )

n_clusters = 4
# Out:
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 20, 64)         │         1,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 20, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ...

# %%
import numpy as np

def permutation_importance(model, X, y, feature_names):
    baseline = model.evaluate(X, y, verbose=0)[1]  # baseline accuracy
    importances = []
    for i in range(X.shape[-1]):
        X_perm = X.copy()
        X_perm[:, :, i] = np.random.permutation(X_perm[:, :, i])
        score = model.evaluate(X_perm, y, verbose=0)[1]
        importances.append(baseline - score)
    return dict(zip(feature_names, importances))

# %%
feature_cols = [
    'mean_current',
    'mean_minus2',
    'mean_minus1',
    'mean_plus1',
    'mean_plus2'
]

feature_importances = permutation_importance(model_4, X_test_4, y_test_4, feature_cols)
print("Permutation Importances:", feature_importances)
# Out:
# Permutation Importances: {'mean_current': 0.2996746897697449, 'mean_minus2': 0.004704654216766357, 'mean_minus1': 0.26971960067749023, 'mean_plus1': 0.24572086334228516, 'mean_plus2': 0.005355417728424072}

# %%
from collections import defaultdict
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

y_pred_proba_4 = model_4.predict(X_test_4)           # (n_traces, 20, n_clusters)
y_pred_4 = np.argmax(y_pred_proba_4, axis=-1)      # (n_traces, 20)

y_pred_flat_4 = y_pred_4.flatten()                 # (n_traces * 20,)
y_test_flat_4 = y_test_4.flatten()                 # (n_traces * 20,)

cm = confusion_matrix(y_test_flat_4, y_pred_flat_4)
# cm_norm = cm.astype(float) / cm.sum(axis=1, keepdims=True)

aa_to_cluster = get_clusters(n_clusters)
cluster_to_aas = defaultdict(list)
for aa, cluster in aa_to_cluster.items():
    cluster_to_aas[cluster].append(aa)

# 0-indexed to match model output
tick_labels = [str(sorted(cluster_to_aas[c + 1])) for c in range(n_clusters)]

fig, ax = plt.subplots(1, 1, figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=ax,
            xticklabels=tick_labels, yticklabels=tick_labels)
ax.set_xlabel('Predicted')
ax.set_ylabel('Actual')
ax.set_title(f'CNN n_clusters={n_clusters} — Counts')
ax.tick_params(axis='x', rotation=45)
ax.tick_params(axis='y', rotation=0)
plt.tight_layout()
plt.show()
print(classification_report(y_test_flat_4, y_pred_flat_4, target_names=tick_labels))
# Out:
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step
#                                 precision    recall  f1-score   support
#
#                     ['R', 'W']       0.91      0.84      0.87     19899
# ['F', 'I', 'K', 'L', 'M', 'Y']       0.89      0.93      0.91     59543
# ['A', 'D', 'E', 'G', 'N', 'S']       0.91      0.89      0.90     60257
# ['C', 'H', 'P', 'Q', 'T', 'V']       0.85      0.85      0.85     59921
#
#                       accuracy                           0.89    199620
#                      macro avg       0.89      0.88      0.88    199620
#                   weighted avg       0.89      0.89      0.89    199620

# %% [markdown]
# ### 5 Cluster CNN

# %%
model_5, history_5, X_test_5, y_test_5 = cnn_sweep(n_clusters=5, train=train_raw, test=test_raw)
# Out:
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_3 (Conv1D)               │ (None, 20, 64)         │         1,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 20, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ...

# %%
from collections import defaultdict
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

n_clusters = 5
y_pred_proba_5 = model_5.predict(X_test_5)           # (n_traces, 20, n_clusters)
y_pred_5 = np.argmax(y_pred_proba_5, axis=-1)      # (n_traces, 20)

y_pred_flat_5 = y_pred_5.flatten()                 # (n_traces * 20,)
y_test_flat_5 = y_test_5.flatten()                 # (n_traces * 20,)

cm = confusion_matrix(y_test_flat_5, y_pred_flat_5)
# cm_norm = cm.astype(float) / cm.sum(axis=1, keepdims=True)

aa_to_cluster = get_clusters(n_clusters)
cluster_to_aas = defaultdict(list)
for aa, cluster in aa_to_cluster.items():
    cluster_to_aas[cluster].append(aa)

# 0-indexed to match model output
tick_labels = [str(sorted(cluster_to_aas[c + 1])) for c in range(n_clusters)]

fig, ax = plt.subplots(1, 1, figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=ax,
            xticklabels=tick_labels, yticklabels=tick_labels)
ax.set_xlabel('Predicted')
ax.set_ylabel('Actual')
ax.set_title(f'CNN n_clusters={n_clusters} — Counts')
ax.tick_params(axis='x', rotation=45)
ax.tick_params(axis='y', rotation=0)
plt.tight_layout()
plt.show()
print(classification_report(y_test_flat_5, y_pred_flat_5, target_names=tick_labels))
# Out:
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
#                                 precision    recall  f1-score   support
#
#                     ['R', 'W']       0.90      0.84      0.87     19899
# ['F', 'I', 'K', 'L', 'M', 'Y']       0.89      0.93      0.91     59543
# ['A', 'D', 'E', 'G', 'N', 'S']       0.91      0.89      0.90     60257
#                     ['H', 'V']       0.70      0.56      0.62     20100
#           ['C', 'P', 'Q', 'T']       0.72      0.80      0.76     39821
#
#                       accuracy                           0.85    199620
#                      macro avg       0.83      0.80      0.81    199620
#                   weighted avg       0.85      0.85      0.84    199620

# %% [markdown]
# ### 6 clusters

# %%
model_6, history_6, X_test_6, y_test_6 = cnn_sweep(n_clusters=6, train=train_raw, test=test_raw)
n_clusters = 6
# Out:
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_6 (Conv1D)               │ (None, 20, 64)         │         1,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 20, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ...

# %%
from collections import defaultdict
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

y_pred_proba_6 = model_6.predict(X_test_6)           # (n_traces, 20, n_clusters)
y_pred_6 = np.argmax(y_pred_proba_6, axis=-1)      # (n_traces, 20)

y_pred_flat_6 = y_pred_6.flatten()                 # (n_traces * 20,)
y_test_flat_6 = y_test_6.flatten()                 # (n_traces * 20,)

cm = confusion_matrix(y_test_flat_6, y_pred_flat_6)
# cm_norm = cm.astype(float) / cm.sum(axis=1, keepdims=True)

aa_to_cluster = get_clusters(n_clusters)
cluster_to_aas = defaultdict(list)
for aa, cluster in aa_to_cluster.items():
    cluster_to_aas[cluster].append(aa)

# 0-indexed to match model output
tick_labels = [str(sorted(cluster_to_aas[c + 1])) for c in range(n_clusters)]

fig, ax = plt.subplots(1, 1, figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=ax,
            xticklabels=tick_labels, yticklabels=tick_labels)
ax.set_xlabel('Predicted')
ax.set_ylabel('Actual')
ax.set_title(f'CNN n_clusters={n_clusters} — Counts')
ax.tick_params(axis='x', rotation=45)
ax.tick_params(axis='y', rotation=0)
plt.tight_layout()
plt.show()
print(classification_report(y_test_flat_6, y_pred_flat_6, target_names=tick_labels))
# Out:
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step
#                                 precision    recall  f1-score   support
#
#                     ['R', 'W']       0.91      0.82      0.86     19899
# ['F', 'I', 'K', 'L', 'M', 'Y']       0.89      0.93      0.91     59543
#                     ['D', 'G']       0.82      0.85      0.84     20208
#           ['A', 'E', 'N', 'S']       0.77      0.74      0.76     40049
#                     ['H', 'V']       0.68      0.54      0.60     20100
#           ['C', 'P', 'Q', 'T']       0.71      0.79      0.75     39821
#
#                       accuracy                           0.81    199620
#                      macro avg       0.80      0.78      0.79    199620
#                   weighted avg       0.80      0.81      0.80    199620

# %% [markdown]
# ### 7 clusters

# %%
model_7, history_7, X_test_7, y_test_7 = cnn_sweep(n_clusters=7, train=train_raw, test=test_raw)
n_clusters = 7
# Out:
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_3 (Conv1D)               │ (None, 20, 64)         │         1,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 20, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ...

# %%
import numpy as np

def permutation_importance(model, X, y, feature_names):
    baseline = model.evaluate(X, y, verbose=0)[1]  # baseline accuracy
    importances = []
    for i in range(X.shape[-1]):
        X_perm = X.copy()
        X_perm[:, :, i] = np.random.permutation(X_perm[:, :, i])
        score = model.evaluate(X_perm, y, verbose=0)[1]
        importances.append(baseline - score)
    return dict(zip(feature_names, importances))

# %%
feature_cols = [
    'mean_current',
    'mean_minus2',
    'mean_minus1',
    'mean_plus1',
    'mean_plus2'
]

feature_importances = permutation_importance(model_7, X_test_7, y_test_7, feature_cols)
print("Permutation Importances:", feature_importances)
# Out:
# Permutation Importances: {'mean_current': 0.4532783031463623, 'mean_minus2': 0.025625646114349365, 'mean_minus1': 0.3199700713157654, 'mean_plus1': 0.294169157743454, 'mean_plus2': 0.021821796894073486}

# %%
from collections import defaultdict
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

y_pred_proba_7 = model_7.predict(X_test_7)           # (n_traces, 20, n_clusters)
y_pred_7 = np.argmax(y_pred_proba_7, axis=-1)      # (n_traces, 20)

y_pred_flat_7 = y_pred_7.flatten()                 # (n_traces * 20,)
y_test_flat_7 = y_test_7.flatten()                 # (n_traces * 20,)

cm = confusion_matrix(y_test_flat_7, y_pred_flat_7)
# cm_norm = cm.astype(float) / cm.sum(axis=1, keepdims=True)

aa_to_cluster = get_clusters(n_clusters)
cluster_to_aas = defaultdict(list)
for aa, cluster in aa_to_cluster.items():
    cluster_to_aas[cluster].append(aa)

# 0-indexed to match model output
tick_labels = [str(sorted(cluster_to_aas[c + 1])) for c in range(n_clusters)]

fig, ax = plt.subplots(1, 1, figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=ax,
            xticklabels=tick_labels, yticklabels=tick_labels)
ax.set_xlabel('Predicted')
ax.set_ylabel('Actual')
ax.set_title(f'CNN n_clusters={n_clusters} — Counts')
ax.tick_params(axis='x', rotation=45)
ax.tick_params(axis='y', rotation=0)
plt.tight_layout()
plt.show()
print(classification_report(y_test_flat_7, y_pred_flat_7, target_names=tick_labels))
# Out:
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
#                       precision    recall  f1-score   support
#
#           ['R', 'W']       0.86      0.90      0.88     19899
#           ['F', 'K']       0.64      0.45      0.53     19770
# ['I', 'L', 'M', 'Y']       0.72      0.85      0.78     39773
#           ['D', 'G']       0.88      0.79      0.83     20208
# ['A', 'E', 'N', 'S']       0.78      0.75      0.77     40049
#           ['H', 'V']       0.69      0.56      0.62     20100
# ['C', 'P', 'Q', 'T']       0.72      0.81      0.76     39821
#
#             accuracy                           0.75    199620
#            macro avg       0.76      0.73      0.74    199620
#         weighted avg       0.75      0.75      0.75    199620

# %%
def make_tick_labels(n_clusters):
    aa_to_cluster = get_clusters(n_clusters)
    cluster_to_aas = defaultdict(list)
    for aa, cluster in aa_to_cluster.items():
        cluster_to_aas[cluster].append(aa)
    return [str(sorted(cluster_to_aas[c + 1])) for c in range(n_clusters)]

print('------------------------CNN n_clusters=4-------------------------')
print(classification_report(y_test_flat_4, y_pred_flat_4, target_names=make_tick_labels(4)))

print('------------------------CNN n_clusters=5-------------------------')
print(classification_report(y_test_flat_5, y_pred_flat_5, target_names=make_tick_labels(5)))

print('------------------------CNN n_clusters=6-------------------------')
print(classification_report(y_test_flat_6, y_pred_flat_6, target_names=make_tick_labels(6)))

print('------------------------CNN n_clusters=7-------------------------')
print(classification_report(y_test_flat_7, y_pred_flat_7, target_names=make_tick_labels(7)))
# Out:
# ------------------------CNN n_clusters=4-------------------------
#                                 precision    recall  f1-score   support
#
#                     ['R', 'W']       0.91      0.84      0.87     19899
# ['F', 'I', 'K', 'L', 'M', 'Y']       0.89      0.93      0.91     59543
# ['A', 'D', 'E', 'G', 'N', 'S']       0.91      0.89      0.90     60257
# ['C', 'H', 'P', 'Q', 'T', 'V']       0.85      0.85      0.85     59921
#
#                       accuracy                           0.89    199620
#                      macro avg       0.89      0.88      0.88    199620
#                   weighted avg       0.89      0.89      0.89    199620
#
# ------------------------CNN n_clusters=5-------------------------
#                                 precision    recall  f1-score   support
#
#                     ['R', 'W']       0.90      0.84      0.87     19899
# ['F', 'I', 'K', 'L', 'M', 'Y']       0.89      0.93      0.91     59543
# ...

# %%
accuracy_4 = np.mean(y_pred_flat_4 == y_test_flat_4)
accuracy_5 = np.mean(y_pred_flat_5 == y_test_flat_5)
accuracy_6 = np.mean(y_pred_flat_6 == y_test_flat_6)
accuracy_7 = np.mean(y_pred_flat_7 == y_test_flat_7)


plt.figure(figsize=(8, 6))
sns.barplot(x=['4', '5', '6', '7'], y=[accuracy_4, accuracy_5, accuracy_6, accuracy_7], palette='viridis')
plt.xlabel('Number of Clusters')
plt.ylabel('Overall Accuracy')
plt.title('CNN Accuracy by Number of Clusters')
plt.ylim(0, 1)
plt.yticks(np.arange(0, 1.1, 0.05))
plt.tight_layout()
plt.show()
# Out:
# /var/folders/ck/1nxbm2p53kx6t3f6p6jhsfxc0000gn/T/ipykernel_67253/2203320861.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=['4', '5', '6', '7'], y=[accuracy_4, accuracy_5, accuracy_6, accuracy_7], palette='viridis')

# %%
print(f'CNN n_clusters=4 Accuracy: {accuracy_4:.2f}')
print(f'CNN n_clusters=5 Accuracy: {accuracy_5:.2f}')
print(f'CNN n_clusters=6 Accuracy: {accuracy_6:.2f}')
print(f'CNN n_clusters=7 Accuracy: {accuracy_7:.2f}')
# Out:
# CNN n_clusters=4 Accuracy: 0.89
# CNN n_clusters=5 Accuracy: 0.85
# CNN n_clusters=6 Accuracy: 0.81
# CNN n_clusters=7 Accuracy: 0.75

# %%
model_7.save('model7.keras')
np.save('X_test_7.npy', X_test_7)
np.save('y_test_7.npy', y_test_7)
# Out:
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# ...
