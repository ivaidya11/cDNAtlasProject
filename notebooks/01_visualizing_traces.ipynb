# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

db = pd.read_csv('../data/nanopore_trace_database.csv')

# %%
IOS = 240

# %%
from logic.plot_trace import plot_trace

# %%
trace_id = 800

plot_trace(db, trace_id)
# Out:
# <Axes: title={'center': 'Trace 800 — Peptide: NLSHSAPTDTVNSRRKTKPC'}, xlabel='Time (ms)', ylabel='Current (pA)'>
