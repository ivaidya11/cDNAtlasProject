# %%
import sys, os
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..')))

from logic.cnn_logic import cnn_sweep
import numpy as np
import tensorflow as tf
from logic.database import AA_PROPERTIES
import pandas as pd
from logic.clustering_cnn import get_clusters

# %%
train_raw = pd.read_csv('../data/nanopore_feature_by_cluster.csv')
test_raw = pd.read_csv('../data/randomcontrol_feature_by_cluster.csv')

# %% [markdown]
# ### 4 Cluster CNN

# %%
model_4, history_4, X_test_4, y_test_4 = cnn_sweep(
    n_clusters=4, train=train_raw, test=test_raw
    )

n_clusters = 4
# Out:
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 20, 64)         │         1,984 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 20, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 20, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 20, 128)        │        41,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 20, 128)        │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 20, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 20, 128)        │        49,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 20, 128)        │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 20, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 20, 64)         │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 20, 4)          │           260 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 102,148 (399.02 KB)
#  Trainable params: 101,508 (396.52 KB)
#  Non-trainable params: 640 (2.50 KB)
# Epoch 1/100
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.6342 - loss: 0.8170 - val_accuracy: 0.7266 - val_loss: 0.6042 - learning_rate: 0.0010
# Epoch 2/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7513 - loss: 0.5611
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7736 - loss: 0.5117 - val_accuracy: 0.7982 - val_loss: 0.4543 - learning_rate: 0.0010
# Epoch 3/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7823 - loss: 0.4954
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7875 - loss: 0.4815 - val_accuracy: 0.8133 - val_loss: 0.4261 - learning_rate: 0.0010
# Epoch 4/100
#  22/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7873 - loss: 0.4765
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7968 - loss: 0.4619 - val_accuracy: 0.8335 - val_loss: 0.3850 - learning_rate: 0.0010
# Epoch 5/100
#  24/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7983 - loss: 0.4656
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7971 - loss: 0.4622 - val_accuracy: 0.7942 - val_loss: 0.4597 - learning_rate: 0.0010
# Epoch 6/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7989 - loss: 0.4571
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8036 - loss: 0.4483 - val_accuracy: 0.7025 - val_loss: 0.6573 - learning_rate: 0.0010
# Epoch 7/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8008 - loss: 0.4431
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8058 - loss: 0.4450 - val_accuracy: 0.7870 - val_loss: 0.4667 - learning_rate: 0.0010
# Epoch 8/100
#  21/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7975 - loss: 0.4507
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.8102 - loss: 0.4345 - val_accuracy: 0.8464 - val_loss: 0.3604 - learning_rate: 5.0000e-04
# Epoch 9/100
#  24/312 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8153 - loss: 0.4312
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8110 - loss: 0.4316 - val_accuracy: 0.8393 - val_loss: 0.3709 - learning_rate: 5.0000e-04
# Epoch 10/100
#  24/312 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8110 - loss: 0.4342
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8106 - loss: 0.4313 - val_accuracy: 0.8415 - val_loss: 0.3645 - learning_rate: 5.0000e-04
# Epoch 11/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8088 - loss: 0.4351
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8137 - loss: 0.4261 - val_accuracy: 0.8342 - val_loss: 0.3790 - learning_rate: 5.0000e-04
# Epoch 12/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8049 - loss: 0.4429
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8157 - loss: 0.4235 - val_accuracy: 0.8472 - val_loss: 0.3568 - learning_rate: 2.5000e-04
# Epoch 13/100
#  23/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8145 - loss: 0.4157
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8161 - loss: 0.4194 - val_accuracy: 0.8302 - val_loss: 0.3896 - learning_rate: 2.5000e-04
# Epoch 14/100
#  23/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8121 - loss: 0.4274
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8168 - loss: 0.4206 - val_accuracy: 0.8497 - val_loss: 0.3569 - learning_rate: 2.5000e-04
# Epoch 15/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8194 - loss: 0.4174
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8165 - loss: 0.4185 - val_accuracy: 0.8443 - val_loss: 0.3637 - learning_rate: 2.5000e-04
# Epoch 16/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8250 - loss: 0.4074
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8159 - loss: 0.4197 - val_accuracy: 0.8424 - val_loss: 0.3651 - learning_rate: 2.5000e-04
# Epoch 17/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8244 - loss: 0.4091
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8174 - loss: 0.4180 - val_accuracy: 0.8492 - val_loss: 0.3539 - learning_rate: 2.5000e-04
# Epoch 18/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8199 - loss: 0.4123
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8201 - loss: 0.4137 - val_accuracy: 0.8512 - val_loss: 0.3489 - learning_rate: 1.2500e-04
# Epoch 19/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8214 - loss: 0.4193
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8189 - loss: 0.4128 - val_accuracy: 0.8518 - val_loss: 0.3489 - learning_rate: 1.2500e-04
# Epoch 20/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8217 - loss: 0.4182
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8190 - loss: 0.4125 - val_accuracy: 0.8521 - val_loss: 0.3463 - learning_rate: 1.2500e-04
# Epoch 21/100
#  16/312 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8185 - loss: 0.4137
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8194 - loss: 0.4133 - val_accuracy: 0.8493 - val_loss: 0.3524 - learning_rate: 1.2500e-04
# Epoch 22/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8286 - loss: 0.4014
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8197 - loss: 0.4121 - val_accuracy: 0.8480 - val_loss: 0.3565 - learning_rate: 1.2500e-04
# Epoch 23/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8234 - loss: 0.4051
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8204 - loss: 0.4107 - val_accuracy: 0.8507 - val_loss: 0.3494 - learning_rate: 1.2500e-04
# Epoch 24/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8213 - loss: 0.3977
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8203 - loss: 0.4112 - val_accuracy: 0.8524 - val_loss: 0.3468 - learning_rate: 6.2500e-05
# Epoch 25/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8121 - loss: 0.4277
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8219 - loss: 0.4095 - val_accuracy: 0.8525 - val_loss: 0.3472 - learning_rate: 6.2500e-05
# Epoch 26/100
#  24/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8234 - loss: 0.4127
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8213 - loss: 0.4100 - val_accuracy: 0.8519 - val_loss: 0.3493 - learning_rate: 6.2500e-05
# Epoch 27/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8154 - loss: 0.4136
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8200 - loss: 0.4105 - val_accuracy: 0.8520 - val_loss: 0.3475 - learning_rate: 6.2500e-05
# Epoch 28/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8153 - loss: 0.4194
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8215 - loss: 0.4078 - val_accuracy: 0.8522 - val_loss: 0.3480 - learning_rate: 6.2500e-05
# Epoch 29/100
#  24/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8277 - loss: 0.4032
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8222 - loss: 0.4085 - val_accuracy: 0.8532 - val_loss: 0.3464 - learning_rate: 3.1250e-05
# Epoch 30/100
#  13/312 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8155 - loss: 0.4250
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8219 - loss: 0.4083 - val_accuracy: 0.8494 - val_loss: 0.3548 - learning_rate: 3.1250e-05
# Epoch 31/100
#  22/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8266 - loss: 0.4065
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8209 - loss: 0.4087 - val_accuracy: 0.8531 - val_loss: 0.3459 - learning_rate: 3.1250e-05
# Epoch 32/100
#  18/312 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8079 - loss: 0.4270
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8219 - loss: 0.4080 - val_accuracy: 0.8535 - val_loss: 0.3469 - learning_rate: 3.1250e-05
# Epoch 33/100
#  20/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8211 - loss: 0.4003
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8212 - loss: 0.4071 - val_accuracy: 0.8517 - val_loss: 0.3504 - learning_rate: 3.1250e-05
# Epoch 34/100
#  14/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8225 - loss: 0.4067
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8220 - loss: 0.4083 - val_accuracy: 0.8523 - val_loss: 0.3477 - learning_rate: 3.1250e-05
# Epoch 35/100
#  18/312 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8190 - loss: 0.4157
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8214 - loss: 0.4078 - val_accuracy: 0.8524 - val_loss: 0.3452 - learning_rate: 3.1250e-05
# Epoch 36/100
#  22/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8118 - loss: 0.4230
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8223 - loss: 0.4066 - val_accuracy: 0.8524 - val_loss: 0.3457 - learning_rate: 1.5625e-05
# Epoch 37/100
#  22/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8175 - loss: 0.4088
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8214 - loss: 0.4083 - val_accuracy: 0.8524 - val_loss: 0.3458 - learning_rate: 1.5625e-05
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)

# %%
from collections import defaultdict
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

y_pred_proba_4 = model_4.predict(X_test_4)           # (n_traces, 20, n_clusters)
y_pred_4 = np.argmax(y_pred_proba_4, axis=-1)      # (n_traces, 20)

y_pred_flat_4 = y_pred_4.flatten()                 # (n_traces * 20,)
y_test_flat_4 = y_test_4.flatten()                 # (n_traces * 20,)

cm = confusion_matrix(y_test_flat_4, y_pred_flat_4)
# cm_norm = cm.astype(float) / cm.sum(axis=1, keepdims=True)

aa_to_cluster = get_clusters(n_clusters)
cluster_to_aas = defaultdict(list)
for aa, cluster in aa_to_cluster.items():
    cluster_to_aas[cluster].append(aa)

# 0-indexed to match model output
tick_labels = [str(sorted(cluster_to_aas[c + 1])) for c in range(n_clusters)]

fig, ax = plt.subplots(1, 1, figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=ax,
            xticklabels=tick_labels, yticklabels=tick_labels)
ax.set_xlabel('Predicted')
ax.set_ylabel('Actual')
ax.set_title(f'CNN n_clusters={n_clusters} — Counts')
ax.tick_params(axis='x', rotation=45)
ax.tick_params(axis='y', rotation=0)
plt.tight_layout()
plt.show()
print(classification_report(y_test_flat_4, y_pred_flat_4, target_names=tick_labels))
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#                                      precision    recall  f1-score   support
#
# ['F', 'I', 'K', 'L', 'R', 'W', 'Y']       0.91      0.96      0.93     13984
#                ['D', 'E', 'G', 'S']       0.90      0.86      0.88      8054
#           ['A', 'C', 'N', 'P', 'T']       0.79      0.83      0.81     10039
#                ['H', 'M', 'Q', 'V']       0.79      0.68      0.73      7883
#
#                            accuracy                           0.85     39960
#                           macro avg       0.85      0.83      0.84     39960
#                        weighted avg       0.85      0.85      0.85     39960

# %% [markdown]
# ### 5 Cluster CNN

# %%
model_5, history_5, X_test_5, y_test_5 = cnn_sweep(n_clusters=5, train=train_raw, test=test_raw)
# Out:
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_3 (Conv1D)               │ (None, 20, 64)         │         1,984 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 20, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 20, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_4 (Conv1D)               │ (None, 20, 128)        │        41,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 20, 128)        │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 20, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_5 (Conv1D)               │ (None, 20, 128)        │        49,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 20, 128)        │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 20, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 20, 64)         │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 20, 5)          │           325 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 102,213 (399.27 KB)
#  Trainable params: 101,573 (396.77 KB)
#  Non-trainable params: 640 (2.50 KB)
# Epoch 1/100
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5842 - loss: 0.9247 - val_accuracy: 0.7325 - val_loss: 0.6087 - learning_rate: 0.0010
# Epoch 2/100
#  23/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7258 - loss: 0.6280
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7280 - loss: 0.6123 - val_accuracy: 0.8037 - val_loss: 0.4736 - learning_rate: 0.0010
# Epoch 3/100
#  23/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7405 - loss: 0.5936
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7443 - loss: 0.5805 - val_accuracy: 0.7957 - val_loss: 0.4703 - learning_rate: 0.0010
# Epoch 4/100
#  24/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7563 - loss: 0.5576
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7529 - loss: 0.5627 - val_accuracy: 0.7829 - val_loss: 0.4940 - learning_rate: 0.0010
# Epoch 5/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7564 - loss: 0.5592
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7570 - loss: 0.5536 - val_accuracy: 0.8144 - val_loss: 0.4490 - learning_rate: 0.0010
# Epoch 6/100
#  24/312 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7542 - loss: 0.5602
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7568 - loss: 0.5492 - val_accuracy: 0.7731 - val_loss: 0.5183 - learning_rate: 0.0010
# Epoch 7/100
#  11/312 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.7607 - loss: 0.5436
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7622 - loss: 0.5407 - val_accuracy: 0.8140 - val_loss: 0.4445 - learning_rate: 0.0010
# Epoch 8/100
#  24/312 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7610 - loss: 0.5388
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7632 - loss: 0.5361 - val_accuracy: 0.8047 - val_loss: 0.4499 - learning_rate: 0.0010
# Epoch 9/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7806 - loss: 0.5075
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7720 - loss: 0.5201 - val_accuracy: 0.8115 - val_loss: 0.4410 - learning_rate: 5.0000e-04
# Epoch 10/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7766 - loss: 0.5149
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7739 - loss: 0.5167 - val_accuracy: 0.8199 - val_loss: 0.4272 - learning_rate: 5.0000e-04
# Epoch 11/100
#  24/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7810 - loss: 0.4956
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7746 - loss: 0.5144 - val_accuracy: 0.8209 - val_loss: 0.4266 - learning_rate: 5.0000e-04
# Epoch 12/100
#  12/312 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.7719 - loss: 0.5234
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7770 - loss: 0.5118 - val_accuracy: 0.8206 - val_loss: 0.4251 - learning_rate: 5.0000e-04
# Epoch 13/100
#  24/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7803 - loss: 0.5101
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7751 - loss: 0.5131 - val_accuracy: 0.8148 - val_loss: 0.4357 - learning_rate: 5.0000e-04
# Epoch 14/100
#  23/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7688 - loss: 0.5224
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7769 - loss: 0.5111 - val_accuracy: 0.8233 - val_loss: 0.4225 - learning_rate: 5.0000e-04
# Epoch 15/100
#  21/312 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.7694 - loss: 0.5161
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7776 - loss: 0.5089 - val_accuracy: 0.8186 - val_loss: 0.4272 - learning_rate: 5.0000e-04
# Epoch 16/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7912 - loss: 0.4949
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7787 - loss: 0.5066 - val_accuracy: 0.8080 - val_loss: 0.4473 - learning_rate: 5.0000e-04
# Epoch 17/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7688 - loss: 0.5234
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7765 - loss: 0.5099 - val_accuracy: 0.8140 - val_loss: 0.4365 - learning_rate: 5.0000e-04
# Epoch 18/100
#  23/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7779 - loss: 0.5175
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7785 - loss: 0.5062 - val_accuracy: 0.8245 - val_loss: 0.4180 - learning_rate: 2.5000e-04
# Epoch 19/100
#  21/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7796 - loss: 0.5099
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7813 - loss: 0.5017 - val_accuracy: 0.8235 - val_loss: 0.4245 - learning_rate: 2.5000e-04
# Epoch 20/100
#  24/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7917 - loss: 0.4897
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7812 - loss: 0.5011 - val_accuracy: 0.8229 - val_loss: 0.4151 - learning_rate: 2.5000e-04
# Epoch 21/100
#  22/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7841 - loss: 0.4968
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7821 - loss: 0.4987 - val_accuracy: 0.8185 - val_loss: 0.4239 - learning_rate: 2.5000e-04
# Epoch 22/100
#  24/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7778 - loss: 0.5103
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7831 - loss: 0.4951 - val_accuracy: 0.8261 - val_loss: 0.4119 - learning_rate: 1.2500e-04
# Epoch 23/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7737 - loss: 0.5160
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7829 - loss: 0.4967 - val_accuracy: 0.8231 - val_loss: 0.4200 - learning_rate: 1.2500e-04
# Epoch 24/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7841 - loss: 0.5005
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7837 - loss: 0.4950 - val_accuracy: 0.8269 - val_loss: 0.4111 - learning_rate: 1.2500e-04
# Epoch 25/100
#  23/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7765 - loss: 0.4961
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.7841 - loss: 0.4928 - val_accuracy: 0.8244 - val_loss: 0.4157 - learning_rate: 1.2500e-04
# Epoch 26/100
#  22/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7864 - loss: 0.4896
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7842 - loss: 0.4935 - val_accuracy: 0.8240 - val_loss: 0.4173 - learning_rate: 1.2500e-04
# Epoch 27/100
#  24/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7825 - loss: 0.5072
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7847 - loss: 0.4930 - val_accuracy: 0.8270 - val_loss: 0.4138 - learning_rate: 1.2500e-04
# Epoch 28/100
#  20/312 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.7872 - loss: 0.4787
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7851 - loss: 0.4935 - val_accuracy: 0.8265 - val_loss: 0.4120 - learning_rate: 1.2500e-04
# Epoch 29/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7781 - loss: 0.5018
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7847 - loss: 0.4926 - val_accuracy: 0.8250 - val_loss: 0.4143 - learning_rate: 1.2500e-04
# Epoch 30/100
#  23/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7956 - loss: 0.4695
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7844 - loss: 0.4926 - val_accuracy: 0.8213 - val_loss: 0.4218 - learning_rate: 1.2500e-04
# Epoch 31/100
#   7/312 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.7851 - loss: 0.4955
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.7848 - loss: 0.4929 - val_accuracy: 0.8271 - val_loss: 0.4116 - learning_rate: 6.2500e-05
# Epoch 32/100
#  21/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7903 - loss: 0.4884
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.7852 - loss: 0.4901 - val_accuracy: 0.8269 - val_loss: 0.4109 - learning_rate: 6.2500e-05
# Epoch 33/100
#  20/312 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.7983 - loss: 0.4767
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.7861 - loss: 0.4901 - val_accuracy: 0.8274 - val_loss: 0.4108 - learning_rate: 6.2500e-05
# Epoch 34/100
#  20/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7786 - loss: 0.5082
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.7852 - loss: 0.4921 - val_accuracy: 0.8261 - val_loss: 0.4136 - learning_rate: 6.2500e-05
# Epoch 35/100
#  22/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7944 - loss: 0.4768
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7860 - loss: 0.4907 - val_accuracy: 0.8274 - val_loss: 0.4116 - learning_rate: 6.2500e-05
# Epoch 36/100
#  23/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7891 - loss: 0.4885
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7868 - loss: 0.4912 - val_accuracy: 0.8257 - val_loss: 0.4117 - learning_rate: 6.2500e-05
# Epoch 37/100
#  23/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7930 - loss: 0.4756
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.7867 - loss: 0.4887 - val_accuracy: 0.8274 - val_loss: 0.4102 - learning_rate: 3.1250e-05
# Epoch 38/100
#  23/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7909 - loss: 0.4817
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7875 - loss: 0.4871 - val_accuracy: 0.8284 - val_loss: 0.4089 - learning_rate: 3.1250e-05
# Epoch 39/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7837 - loss: 0.4897
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7875 - loss: 0.4868 - val_accuracy: 0.8277 - val_loss: 0.4105 - learning_rate: 3.1250e-05
# Epoch 40/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7997 - loss: 0.4720
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7872 - loss: 0.4871 - val_accuracy: 0.8278 - val_loss: 0.4078 - learning_rate: 3.1250e-05
# Epoch 41/100
#  24/312 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7970 - loss: 0.4743
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7865 - loss: 0.4885 - val_accuracy: 0.8275 - val_loss: 0.4089 - learning_rate: 3.1250e-05
# Epoch 42/100
#  22/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7868 - loss: 0.4820
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7868 - loss: 0.4870 - val_accuracy: 0.8277 - val_loss: 0.4092 - learning_rate: 1.5625e-05
# Epoch 43/100
#  20/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7756 - loss: 0.5007
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7871 - loss: 0.4871 - val_accuracy: 0.8286 - val_loss: 0.4081 - learning_rate: 1.5625e-05
# Epoch 44/100
#  22/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7791 - loss: 0.5043
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.7880 - loss: 0.4873 - val_accuracy: 0.8277 - val_loss: 0.4099 - learning_rate: 1.5625e-05
# Epoch 45/100
#  15/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7837 - loss: 0.4843
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7884 - loss: 0.4859 - val_accuracy: 0.8275 - val_loss: 0.4097 - learning_rate: 1.5625e-05
# Epoch 46/100
#  22/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7836 - loss: 0.4951
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7873 - loss: 0.4871 - val_accuracy: 0.8281 - val_loss: 0.4092 - learning_rate: 1.5625e-05
# Epoch 47/100
#  14/312 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.7886 - loss: 0.4855
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7872 - loss: 0.4874 - val_accuracy: 0.8281 - val_loss: 0.4085 - learning_rate: 1.0000e-05
# Epoch 48/100
#  24/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7926 - loss: 0.4802
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7876 - loss: 0.4857 - val_accuracy: 0.8281 - val_loss: 0.4082 - learning_rate: 1.0000e-05
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)

# %%
from collections import defaultdict
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

n_clusters = 5
y_pred_proba_5 = model_5.predict(X_test_5)           # (n_traces, 20, n_clusters)
y_pred_5 = np.argmax(y_pred_proba_5, axis=-1)      # (n_traces, 20)

y_pred_flat_5 = y_pred_5.flatten()                 # (n_traces * 20,)
y_test_flat_5 = y_test_5.flatten()                 # (n_traces * 20,)

cm = confusion_matrix(y_test_flat_5, y_pred_flat_5)
# cm_norm = cm.astype(float) / cm.sum(axis=1, keepdims=True)

aa_to_cluster = get_clusters(n_clusters)
cluster_to_aas = defaultdict(list)
for aa, cluster in aa_to_cluster.items():
    cluster_to_aas[cluster].append(aa)

# 0-indexed to match model output
tick_labels = [str(sorted(cluster_to_aas[c + 1])) for c in range(n_clusters)]

fig, ax = plt.subplots(1, 1, figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=ax,
            xticklabels=tick_labels, yticklabels=tick_labels)
ax.set_xlabel('Predicted')
ax.set_ylabel('Actual')
ax.set_title(f'CNN n_clusters={n_clusters} — Counts')
ax.tick_params(axis='x', rotation=45)
ax.tick_params(axis='y', rotation=0)
plt.tight_layout()
plt.show()
print(classification_report(y_test_flat_5, y_pred_flat_5, target_names=tick_labels))
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#                            precision    recall  f1-score   support
#
#                ['R', 'W']       0.89      0.83      0.86      3982
# ['F', 'I', 'K', 'L', 'Y']       0.82      0.90      0.86     10002
#      ['D', 'E', 'G', 'S']       0.90      0.87      0.88      8054
# ['A', 'C', 'N', 'P', 'T']       0.78      0.85      0.81     10039
#      ['H', 'M', 'Q', 'V']       0.80      0.67      0.73      7883
#
#                  accuracy                           0.83     39960
#                 macro avg       0.84      0.82      0.83     39960
#              weighted avg       0.83      0.83      0.83     39960

# %% [markdown]
# ### 6 clusters

# %%
model_6, history_6, X_test_6, y_test_6 = cnn_sweep(n_clusters=6, train=train_raw, test=test_raw)
n_clusters = 6
# Out:
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_6 (Conv1D)               │ (None, 20, 64)         │         1,984 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 20, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 20, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_7 (Conv1D)               │ (None, 20, 128)        │        41,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 20, 128)        │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 20, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_8 (Conv1D)               │ (None, 20, 128)        │        49,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 20, 128)        │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 20, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 20, 64)         │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 20, 6)          │           390 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 102,278 (399.52 KB)
#  Trainable params: 101,638 (397.02 KB)
#  Non-trainable params: 640 (2.50 KB)
# Epoch 1/100
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5353 - loss: 1.1044 - val_accuracy: 0.6710 - val_loss: 0.7602 - learning_rate: 0.0010
# Epoch 2/100
#  26/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6536 - loss: 0.7903
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6802 - loss: 0.7362 - val_accuracy: 0.7271 - val_loss: 0.6441 - learning_rate: 0.0010
# Epoch 3/100
#   9/312 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - accuracy: 0.6943 - loss: 0.6998
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7039 - loss: 0.6801 - val_accuracy: 0.7655 - val_loss: 0.5534 - learning_rate: 0.0010
# Epoch 4/100
#  27/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7163 - loss: 0.6469
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7153 - loss: 0.6570 - val_accuracy: 0.7639 - val_loss: 0.5483 - learning_rate: 0.0010
# Epoch 5/100
#  28/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7177 - loss: 0.6463
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7213 - loss: 0.6413 - val_accuracy: 0.7710 - val_loss: 0.5408 - learning_rate: 0.0010
# Epoch 6/100
#  28/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7224 - loss: 0.6366
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7253 - loss: 0.6311 - val_accuracy: 0.7726 - val_loss: 0.5329 - learning_rate: 0.0010
# Epoch 7/100
#  28/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7202 - loss: 0.6410
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7289 - loss: 0.6264 - val_accuracy: 0.7709 - val_loss: 0.5322 - learning_rate: 0.0010
# Epoch 8/100
#  27/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7292 - loss: 0.6256
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7298 - loss: 0.6215 - val_accuracy: 0.7729 - val_loss: 0.5414 - learning_rate: 0.0010
# Epoch 9/100
#  16/312 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.7270 - loss: 0.6138
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7332 - loss: 0.6132 - val_accuracy: 0.7735 - val_loss: 0.5239 - learning_rate: 0.0010
# Epoch 10/100
#  28/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7419 - loss: 0.6101
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7348 - loss: 0.6115 - val_accuracy: 0.7766 - val_loss: 0.5171 - learning_rate: 0.0010
# Epoch 11/100
#  28/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7376 - loss: 0.6083
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7362 - loss: 0.6082 - val_accuracy: 0.7824 - val_loss: 0.5128 - learning_rate: 0.0010
# Epoch 12/100
#  22/312 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.7375 - loss: 0.6025
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7347 - loss: 0.6087 - val_accuracy: 0.7874 - val_loss: 0.5034 - learning_rate: 0.0010
# Epoch 13/100
#  26/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7372 - loss: 0.6030
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7386 - loss: 0.6013 - val_accuracy: 0.7657 - val_loss: 0.5434 - learning_rate: 0.0010
# Epoch 14/100
#  27/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7401 - loss: 0.6036
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7389 - loss: 0.6004 - val_accuracy: 0.7844 - val_loss: 0.5092 - learning_rate: 0.0010
# Epoch 15/100
#  27/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7373 - loss: 0.6024
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7405 - loss: 0.5977 - val_accuracy: 0.7769 - val_loss: 0.5167 - learning_rate: 0.0010
# Epoch 16/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7459 - loss: 0.5923
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7438 - loss: 0.5908 - val_accuracy: 0.7918 - val_loss: 0.4976 - learning_rate: 5.0000e-04
# Epoch 17/100
#  28/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7587 - loss: 0.5618
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7466 - loss: 0.5845 - val_accuracy: 0.7870 - val_loss: 0.5108 - learning_rate: 5.0000e-04
# Epoch 18/100
#  27/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7498 - loss: 0.5837
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7472 - loss: 0.5844 - val_accuracy: 0.7930 - val_loss: 0.4967 - learning_rate: 5.0000e-04
# Epoch 19/100
#  27/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7402 - loss: 0.5932
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7464 - loss: 0.5843 - val_accuracy: 0.7935 - val_loss: 0.4910 - learning_rate: 5.0000e-04
# Epoch 20/100
#  27/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7473 - loss: 0.5806
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7457 - loss: 0.5844 - val_accuracy: 0.7933 - val_loss: 0.4942 - learning_rate: 5.0000e-04
# Epoch 21/100
#  27/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7409 - loss: 0.5941
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7458 - loss: 0.5848 - val_accuracy: 0.7852 - val_loss: 0.5083 - learning_rate: 5.0000e-04
# Epoch 22/100
#  28/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7463 - loss: 0.5814
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7469 - loss: 0.5840 - val_accuracy: 0.7955 - val_loss: 0.4888 - learning_rate: 5.0000e-04
# Epoch 23/100
#  28/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7357 - loss: 0.5990
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7488 - loss: 0.5802 - val_accuracy: 0.7767 - val_loss: 0.5180 - learning_rate: 5.0000e-04
# Epoch 24/100
#  28/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7470 - loss: 0.5922
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7493 - loss: 0.5791 - val_accuracy: 0.7950 - val_loss: 0.4899 - learning_rate: 5.0000e-04
# Epoch 25/100
#  23/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7476 - loss: 0.5750
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7508 - loss: 0.5755 - val_accuracy: 0.7940 - val_loss: 0.4875 - learning_rate: 5.0000e-04
# Epoch 26/100
#  27/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7505 - loss: 0.5731
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7507 - loss: 0.5712 - val_accuracy: 0.7939 - val_loss: 0.4896 - learning_rate: 2.5000e-04
# Epoch 27/100
#  26/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7543 - loss: 0.5620
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7516 - loss: 0.5711 - val_accuracy: 0.7960 - val_loss: 0.4847 - learning_rate: 2.5000e-04
# Epoch 28/100
#  26/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7464 - loss: 0.5797
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7528 - loss: 0.5698 - val_accuracy: 0.7958 - val_loss: 0.4851 - learning_rate: 2.5000e-04
# Epoch 29/100
#  28/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7577 - loss: 0.5675
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7541 - loss: 0.5677 - val_accuracy: 0.7890 - val_loss: 0.4984 - learning_rate: 2.5000e-04
# Epoch 30/100
#  26/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7505 - loss: 0.5679
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7527 - loss: 0.5705 - val_accuracy: 0.7970 - val_loss: 0.4823 - learning_rate: 2.5000e-04
# Epoch 31/100
#  27/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7435 - loss: 0.5874
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7526 - loss: 0.5685 - val_accuracy: 0.7919 - val_loss: 0.4983 - learning_rate: 2.5000e-04
# Epoch 32/100
#  28/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7435 - loss: 0.5836
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7546 - loss: 0.5665 - val_accuracy: 0.7902 - val_loss: 0.4942 - learning_rate: 2.5000e-04
# Epoch 33/100
#  28/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7611 - loss: 0.5489
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7551 - loss: 0.5655 - val_accuracy: 0.7961 - val_loss: 0.4864 - learning_rate: 2.5000e-04
# Epoch 34/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7604 - loss: 0.5577
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7562 - loss: 0.5627 - val_accuracy: 0.7963 - val_loss: 0.4825 - learning_rate: 1.2500e-04
# Epoch 35/100
#  23/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7524 - loss: 0.5677
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7571 - loss: 0.5627 - val_accuracy: 0.7958 - val_loss: 0.4815 - learning_rate: 1.2500e-04
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)

# %%
from collections import defaultdict
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

y_pred_proba_6 = model_6.predict(X_test_6)           # (n_traces, 20, n_clusters)
y_pred_6 = np.argmax(y_pred_proba_6, axis=-1)      # (n_traces, 20)

y_pred_flat_6 = y_pred_6.flatten()                 # (n_traces * 20,)
y_test_flat_6 = y_test_6.flatten()                 # (n_traces * 20,)

cm = confusion_matrix(y_test_flat_6, y_pred_flat_6)
# cm_norm = cm.astype(float) / cm.sum(axis=1, keepdims=True)

aa_to_cluster = get_clusters(n_clusters)
cluster_to_aas = defaultdict(list)
for aa, cluster in aa_to_cluster.items():
    cluster_to_aas[cluster].append(aa)

# 0-indexed to match model output
tick_labels = [str(sorted(cluster_to_aas[c + 1])) for c in range(n_clusters)]

fig, ax = plt.subplots(1, 1, figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=ax,
            xticklabels=tick_labels, yticklabels=tick_labels)
ax.set_xlabel('Predicted')
ax.set_ylabel('Actual')
ax.set_title(f'CNN n_clusters={n_clusters} — Counts')
ax.tick_params(axis='x', rotation=45)
ax.tick_params(axis='y', rotation=0)
plt.tight_layout()
plt.show()
print(classification_report(y_test_flat_6, y_pred_flat_6, target_names=tick_labels))
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#                            precision    recall  f1-score   support
#
#                ['R', 'W']       0.88      0.86      0.87      3982
# ['F', 'I', 'K', 'L', 'Y']       0.81      0.91      0.86     10002
#      ['D', 'E', 'G', 'S']       0.91      0.85      0.88      8054
# ['A', 'C', 'N', 'P', 'T']       0.77      0.87      0.82     10039
#                ['H', 'Q']       0.63      0.49      0.55      4041
#                ['M', 'V']       0.64      0.44      0.52      3842
#
#                  accuracy                           0.80     39960
#                 macro avg       0.77      0.74      0.75     39960
#              weighted avg       0.79      0.80      0.79     39960

# %% [markdown]
# ### 7 clusters

# %%
model_7, history_7, X_test_7, y_test_7 = cnn_sweep(n_clusters=7, train=train_raw, test=test_raw)
n_clusters = 7
# Out:
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_9 (Conv1D)               │ (None, 20, 64)         │         1,984 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 20, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 20, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_10 (Conv1D)              │ (None, 20, 128)        │        41,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 20, 128)        │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 20, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_11 (Conv1D)              │ (None, 20, 128)        │        49,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 20, 128)        │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 20, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 20, 64)         │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 20, 7)          │           455 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 102,343 (399.78 KB)
#  Trainable params: 101,703 (397.28 KB)
#  Non-trainable params: 640 (2.50 KB)
# Epoch 1/100
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.4810 - loss: 1.2680 - val_accuracy: 0.4850 - val_loss: 1.2192 - learning_rate: 0.0010
# Epoch 2/100
#  24/312 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5978 - loss: 0.9264
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6187 - loss: 0.8705 - val_accuracy: 0.7064 - val_loss: 0.6723 - learning_rate: 0.0010
# Epoch 3/100
#  24/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6390 - loss: 0.8357
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6474 - loss: 0.8061 - val_accuracy: 0.7311 - val_loss: 0.6429 - learning_rate: 0.0010
# Epoch 4/100
#  20/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6627 - loss: 0.7830
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6602 - loss: 0.7754 - val_accuracy: 0.7052 - val_loss: 0.6825 - learning_rate: 0.0010
# Epoch 5/100
#  26/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6666 - loss: 0.7738
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6683 - loss: 0.7569 - val_accuracy: 0.7474 - val_loss: 0.6128 - learning_rate: 0.0010
# Epoch 6/100
#  26/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6663 - loss: 0.7588
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6728 - loss: 0.7477 - val_accuracy: 0.7406 - val_loss: 0.6178 - learning_rate: 0.0010
# Epoch 7/100
#  26/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6785 - loss: 0.7396
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6765 - loss: 0.7390 - val_accuracy: 0.7299 - val_loss: 0.6316 - learning_rate: 0.0010
# Epoch 8/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6770 - loss: 0.7404
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6801 - loss: 0.7315 - val_accuracy: 0.7341 - val_loss: 0.6138 - learning_rate: 0.0010
# Epoch 9/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6740 - loss: 0.7598
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6871 - loss: 0.7155 - val_accuracy: 0.7513 - val_loss: 0.5953 - learning_rate: 5.0000e-04
# Epoch 10/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6943 - loss: 0.7035
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6906 - loss: 0.7092 - val_accuracy: 0.7498 - val_loss: 0.5867 - learning_rate: 5.0000e-04
# Epoch 11/100
#  27/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6936 - loss: 0.7001
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6909 - loss: 0.7086 - val_accuracy: 0.7456 - val_loss: 0.6005 - learning_rate: 5.0000e-04
# Epoch 12/100
#  26/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6849 - loss: 0.7085
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6923 - loss: 0.7035 - val_accuracy: 0.7464 - val_loss: 0.5962 - learning_rate: 5.0000e-04
# Epoch 13/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7008 - loss: 0.6862
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6967 - loss: 0.6945 - val_accuracy: 0.7577 - val_loss: 0.5818 - learning_rate: 2.5000e-04
# Epoch 14/100
#  26/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6938 - loss: 0.6869
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6958 - loss: 0.6924 - val_accuracy: 0.7592 - val_loss: 0.5764 - learning_rate: 2.5000e-04
# Epoch 15/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6897 - loss: 0.6974
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6967 - loss: 0.6933 - val_accuracy: 0.7583 - val_loss: 0.5750 - learning_rate: 2.5000e-04
# Epoch 16/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6883 - loss: 0.7119
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6982 - loss: 0.6919 - val_accuracy: 0.7517 - val_loss: 0.5896 - learning_rate: 2.5000e-04
# Epoch 17/100
#  26/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6928 - loss: 0.6952
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6990 - loss: 0.6895 - val_accuracy: 0.7569 - val_loss: 0.5796 - learning_rate: 2.5000e-04
# Epoch 18/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6904 - loss: 0.7037
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7001 - loss: 0.6857 - val_accuracy: 0.7610 - val_loss: 0.5687 - learning_rate: 1.2500e-04
# Epoch 19/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6978 - loss: 0.6879
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7018 - loss: 0.6829 - val_accuracy: 0.7608 - val_loss: 0.5704 - learning_rate: 1.2500e-04
# Epoch 20/100
#  24/312 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7007 - loss: 0.6754
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7020 - loss: 0.6836 - val_accuracy: 0.7608 - val_loss: 0.5708 - learning_rate: 1.2500e-04
# Epoch 21/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7041 - loss: 0.6873
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7013 - loss: 0.6841 - val_accuracy: 0.7612 - val_loss: 0.5698 - learning_rate: 1.2500e-04
# Epoch 22/100
#  26/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7066 - loss: 0.6687
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7028 - loss: 0.6812 - val_accuracy: 0.7587 - val_loss: 0.5739 - learning_rate: 1.2500e-04
# Epoch 23/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6948 - loss: 0.6951
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7019 - loss: 0.6838 - val_accuracy: 0.7618 - val_loss: 0.5711 - learning_rate: 1.2500e-04
# Epoch 24/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7114 - loss: 0.6601
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7024 - loss: 0.6796 - val_accuracy: 0.7596 - val_loss: 0.5694 - learning_rate: 1.2500e-04
# Epoch 25/100
#  26/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7026 - loss: 0.6828
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7028 - loss: 0.6793 - val_accuracy: 0.7610 - val_loss: 0.5716 - learning_rate: 1.2500e-04
# Epoch 26/100
#  26/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7047 - loss: 0.6710
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7036 - loss: 0.6804 - val_accuracy: 0.7608 - val_loss: 0.5681 - learning_rate: 1.2500e-04
# Epoch 27/100
#  26/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7036 - loss: 0.6691
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7048 - loss: 0.6763 - val_accuracy: 0.7580 - val_loss: 0.5743 - learning_rate: 6.2500e-05
# Epoch 28/100
#  26/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7015 - loss: 0.6771
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7036 - loss: 0.6781 - val_accuracy: 0.7628 - val_loss: 0.5680 - learning_rate: 6.2500e-05
# Epoch 29/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7028 - loss: 0.6786
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7052 - loss: 0.6755 - val_accuracy: 0.7617 - val_loss: 0.5685 - learning_rate: 6.2500e-05
# Epoch 30/100
#  26/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7004 - loss: 0.6708
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7030 - loss: 0.6774 - val_accuracy: 0.7629 - val_loss: 0.5649 - learning_rate: 6.2500e-05
# Epoch 31/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6937 - loss: 0.7005
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7051 - loss: 0.6761 - val_accuracy: 0.7629 - val_loss: 0.5671 - learning_rate: 6.2500e-05
# Epoch 32/100
#  26/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7039 - loss: 0.6774
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7051 - loss: 0.6753 - val_accuracy: 0.7626 - val_loss: 0.5662 - learning_rate: 6.2500e-05
# Epoch 33/100
#  26/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7044 - loss: 0.6856
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7044 - loss: 0.6760 - val_accuracy: 0.7631 - val_loss: 0.5669 - learning_rate: 6.2500e-05
# Epoch 34/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7150 - loss: 0.6636
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7050 - loss: 0.6751 - val_accuracy: 0.7619 - val_loss: 0.5678 - learning_rate: 6.2500e-05
# Epoch 35/100
#  16/312 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.7145 - loss: 0.6462
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7052 - loss: 0.6751 - val_accuracy: 0.7634 - val_loss: 0.5674 - learning_rate: 6.2500e-05
# Epoch 36/100
#  26/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7081 - loss: 0.6740
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7054 - loss: 0.6736 - val_accuracy: 0.7633 - val_loss: 0.5640 - learning_rate: 6.2500e-05
# Epoch 37/100
#  27/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7092 - loss: 0.6638
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7053 - loss: 0.6744 - val_accuracy: 0.7615 - val_loss: 0.5669 - learning_rate: 6.2500e-05
# Epoch 38/100
#  26/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7021 - loss: 0.6840
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7045 - loss: 0.6736 - val_accuracy: 0.7646 - val_loss: 0.5643 - learning_rate: 6.2500e-05
# Epoch 39/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7093 - loss: 0.6733
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7042 - loss: 0.6755 - val_accuracy: 0.7627 - val_loss: 0.5674 - learning_rate: 6.2500e-05
# Epoch 40/100
#  26/312 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6966 - loss: 0.6895
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7055 - loss: 0.6741 - val_accuracy: 0.7628 - val_loss: 0.5664 - learning_rate: 6.2500e-05
# Epoch 41/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7070 - loss: 0.6804
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7059 - loss: 0.6738 - val_accuracy: 0.7580 - val_loss: 0.5743 - learning_rate: 6.2500e-05
# Epoch 42/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7063 - loss: 0.6711
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7057 - loss: 0.6730 - val_accuracy: 0.7637 - val_loss: 0.5654 - learning_rate: 3.1250e-05
# Epoch 43/100
#  25/312 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7118 - loss: 0.6642
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7064 - loss: 0.6737 - val_accuracy: 0.7634 - val_loss: 0.5671 - learning_rate: 3.1250e-05
# /Users/iravaidya/Documents/Bachelors/BEP/cDNAtlasProject/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:171: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   return np.array(x)

# %%
from collections import defaultdict
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

y_pred_proba_7 = model_7.predict(X_test_7)           # (n_traces, 20, n_clusters)
y_pred_7 = np.argmax(y_pred_proba_7, axis=-1)      # (n_traces, 20)

y_pred_flat_7 = y_pred_7.flatten()                 # (n_traces * 20,)
y_test_flat_7 = y_test_7.flatten()                 # (n_traces * 20,)

cm = confusion_matrix(y_test_flat_7, y_pred_flat_7)
# cm_norm = cm.astype(float) / cm.sum(axis=1, keepdims=True)

aa_to_cluster = get_clusters(n_clusters)
cluster_to_aas = defaultdict(list)
for aa, cluster in aa_to_cluster.items():
    cluster_to_aas[cluster].append(aa)

# 0-indexed to match model output
tick_labels = [str(sorted(cluster_to_aas[c + 1])) for c in range(n_clusters)]

fig, ax = plt.subplots(1, 1, figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=ax,
            xticklabels=tick_labels, yticklabels=tick_labels)
ax.set_xlabel('Predicted')
ax.set_ylabel('Actual')
ax.set_title(f'CNN n_clusters={n_clusters} — Counts')
ax.tick_params(axis='x', rotation=45)
ax.tick_params(axis='y', rotation=0)
plt.tight_layout()
plt.show()
print(classification_report(y_test_flat_7, y_pred_flat_7, target_names=tick_labels))
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#                            precision    recall  f1-score   support
#
#                ['R', 'W']       0.90      0.83      0.86      3982
# ['F', 'I', 'K', 'L', 'Y']       0.81      0.91      0.86     10002
#                ['D', 'G']       0.83      0.84      0.83      4019
#                ['E', 'S']       0.64      0.57      0.60      4035
# ['A', 'C', 'N', 'P', 'T']       0.76      0.87      0.82     10039
#                ['H', 'Q']       0.62      0.48      0.54      4041
#                ['M', 'V']       0.63      0.45      0.53      3842
#
#                  accuracy                           0.76     39960
#                 macro avg       0.74      0.71      0.72     39960
#              weighted avg       0.76      0.76      0.76     39960

# %%
def make_tick_labels(n_clusters):
    aa_to_cluster = get_clusters(n_clusters)
    cluster_to_aas = defaultdict(list)
    for aa, cluster in aa_to_cluster.items():
        cluster_to_aas[cluster].append(aa)
    return [str(sorted(cluster_to_aas[c + 1])) for c in range(n_clusters)]

print('------------------------CNN n_clusters=4-------------------------')
print(classification_report(y_test_flat_4, y_pred_flat_4, target_names=make_tick_labels(4)))

print('------------------------CNN n_clusters=5-------------------------')
print(classification_report(y_test_flat_5, y_pred_flat_5, target_names=make_tick_labels(5)))

print('------------------------CNN n_clusters=6-------------------------')
print(classification_report(y_test_flat_6, y_pred_flat_6, target_names=make_tick_labels(6)))

print('------------------------CNN n_clusters=7-------------------------')
print(classification_report(y_test_flat_7, y_pred_flat_7, target_names=make_tick_labels(7)))
# Out:
# ------------------------CNN n_clusters=4-------------------------
#                                      precision    recall  f1-score   support
#
# ['F', 'I', 'K', 'L', 'R', 'W', 'Y']       0.91      0.96      0.93     13984
#                ['D', 'E', 'G', 'S']       0.90      0.86      0.88      8054
#           ['A', 'C', 'N', 'P', 'T']       0.79      0.83      0.81     10039
#                ['H', 'M', 'Q', 'V']       0.79      0.68      0.73      7883
#
#                            accuracy                           0.85     39960
#                           macro avg       0.85      0.83      0.84     39960
#                        weighted avg       0.85      0.85      0.85     39960
#
# ------------------------CNN n_clusters=5-------------------------
#                            precision    recall  f1-score   support
#
#                ['R', 'W']       0.89      0.83      0.86      3982
# ['F', 'I', 'K', 'L', 'Y']       0.82      0.90      0.86     10002
#      ['D', 'E', 'G', 'S']       0.90      0.87      0.88      8054
# ['A', 'C', 'N', 'P', 'T']       0.78      0.85      0.81     10039
#      ['H', 'M', 'Q', 'V']       0.80      0.67      0.73      7883
#
#                  accuracy                           0.83     39960
#                 macro avg       0.84      0.82      0.83     39960
#              weighted avg       0.83      0.83      0.83     39960
#
# ------------------------CNN n_clusters=6-------------------------
#                            precision    recall  f1-score   support
#
#                ['R', 'W']       0.88      0.86      0.87      3982
# ['F', 'I', 'K', 'L', 'Y']       0.81      0.91      0.86     10002
#      ['D', 'E', 'G', 'S']       0.91      0.85      0.88      8054
# ['A', 'C', 'N', 'P', 'T']       0.77      0.87      0.82     10039
#                ['H', 'Q']       0.63      0.49      0.55      4041
#                ['M', 'V']       0.64      0.44      0.52      3842
#
#                  accuracy                           0.80     39960
#                 macro avg       0.77      0.74      0.75     39960
#              weighted avg       0.79      0.80      0.79     39960
#
# ------------------------CNN n_clusters=7-------------------------
#                            precision    recall  f1-score   support
#
#                ['R', 'W']       0.90      0.83      0.86      3982
# ['F', 'I', 'K', 'L', 'Y']       0.81      0.91      0.86     10002
#                ['D', 'G']       0.83      0.84      0.83      4019
#                ['E', 'S']       0.64      0.57      0.60      4035
# ['A', 'C', 'N', 'P', 'T']       0.76      0.87      0.82     10039
#                ['H', 'Q']       0.62      0.48      0.54      4041
#                ['M', 'V']       0.63      0.45      0.53      3842
#
#                  accuracy                           0.76     39960
#                 macro avg       0.74      0.71      0.72     39960
#              weighted avg       0.76      0.76      0.76     39960
